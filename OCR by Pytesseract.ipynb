# %%
import numpy as np
import cv2 
import pytesseract as pt
import matplotlib.pyplot as plt
# pytesseract.pytesseract.tesseract_cmd = r"D:\Tesseract\tesseract.exe"

# %%
image = cv2.imread('./images/N1.jpeg')
plt.imshow(image)
# plt.show()

# %%
text = pt.image_to_string(image)
print(text)
